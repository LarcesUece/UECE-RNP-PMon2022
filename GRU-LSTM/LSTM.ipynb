# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 6), dpi=100)
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
plt.plot(dataset)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
#fix random seed for reproducibility
tf.random.set_seed(7)

# %%
#load the dataset
dataframe = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
#normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
#30,70
#50,50
#70,30
# Out:
# 616 264

# %%
#convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
#reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
#reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
#create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=150, batch_size=1, verbose=2)
# Out:
# Epoch 1/150
# 614/614 - 2s - loss: 0.0459 - 2s/epoch - 3ms/step
# Epoch 2/150
# 614/614 - 1s - loss: 0.0055 - 510ms/epoch - 831us/step
# Epoch 3/150
# 614/614 - 1s - loss: 0.0055 - 506ms/epoch - 824us/step
# Epoch 4/150
# 614/614 - 1s - loss: 0.0055 - 512ms/epoch - 833us/step
# Epoch 5/150
# 614/614 - 1s - loss: 0.0055 - 532ms/epoch - 866us/step
# Epoch 6/150
# 614/614 - 1s - loss: 0.0055 - 525ms/epoch - 855us/step
# Epoch 7/150
# 614/614 - 1s - loss: 0.0055 - 519ms/epoch - 845us/step
# Epoch 8/150
# 614/614 - 1s - loss: 0.0055 - 517ms/epoch - 842us/step
# Epoch 9/150
# 614/614 - 1s - loss: 0.0054 - 517ms/epoch - 842us/step
# Epoch 10/150
# 614/614 - 1s - loss: 0.0055 - 514ms/epoch - 838us/step
# Epoch 11/150
# 614/614 - 1s - loss: 0.0055 - 508ms/epoch - 827us/step
# Epoch 12/150
# 614/614 - 1s - loss: 0.0054 - 513ms/epoch - 836us/step
# Epoch 13/150
# 614/614 - 1s - loss: 0.0054 - 511ms/epoch - 833us/step
# Epoch 14/150
# 614/614 - 1s - loss: 0.0055 - 515ms/epoch - 839us/step
# Epoch 15/150
# 614/614 - 1s - loss: 0.0054 - 548ms/epoch - 892us/step
# Epoch 16/150
# 614/614 - 1s - loss: 0.0054 - 580ms/epoch - 945us/step
# Epoch 17/150
# 614/614 - 1s - loss: 0.0054 - 550ms/epoch - 896us/step
# Epoch 18/150
# 614/614 - 1s - loss: 0.0055 - 502ms/epoch - 818us/step
# Epoch 19/150
# 614/614 - 0s - loss: 0.0054 - 496ms/epoch - 808us/step
# Epoch 20/150
# 614/614 - 1s - loss: 0.0054 - 512ms/epoch - 834us/step
# Epoch 21/150
# 614/614 - 0s - loss: 0.0055 - 488ms/epoch - 796us/step
# Epoch 22/150
# 614/614 - 0s - loss: 0.0055 - 491ms/epoch - 800us/step
# Epoch 23/150
# 614/614 - 1s - loss: 0.0055 - 503ms/epoch - 819us/step
# Epoch 24/150
# 614/614 - 0s - loss: 0.0055 - 493ms/epoch - 803us/step
# Epoch 25/150
# 614/614 - 0s - loss: 0.0054 - 495ms/epoch - 805us/step
# Epoch 26/150
# 614/614 - 0s - loss: 0.0054 - 486ms/epoch - 792us/step
# Epoch 27/150
# 614/614 - 0s - loss: 0.0055 - 475ms/epoch - 773us/step
# Epoch 28/150
# 614/614 - 0s - loss: 0.0054 - 488ms/epoch - 794us/step
# Epoch 29/150
# 614/614 - 0s - loss: 0.0054 - 498ms/epoch - 811us/step
# Epoch 30/150
# 614/614 - 0s - loss: 0.0054 - 494ms/epoch - 805us/step
# Epoch 31/150
# 614/614 - 0s - loss: 0.0055 - 497ms/epoch - 809us/step
# Epoch 32/150
# 614/614 - 0s - loss: 0.0054 - 487ms/epoch - 794us/step
# Epoch 33/150
# 614/614 - 0s - loss: 0.0054 - 495ms/epoch - 806us/step
# Epoch 34/150
# 614/614 - 0s - loss: 0.0054 - 500ms/epoch - 814us/step
# Epoch 35/150
# 614/614 - 0s - loss: 0.0055 - 481ms/epoch - 783us/step
# Epoch 36/150
# 614/614 - 1s - loss: 0.0055 - 500ms/epoch - 814us/step
# Epoch 37/150
# 614/614 - 0s - loss: 0.0055 - 500ms/epoch - 814us/step
# Epoch 38/150
# 614/614 - 0s - loss: 0.0055 - 491ms/epoch - 800us/step
# Epoch 39/150
# 614/614 - 0s - loss: 0.0054 - 487ms/epoch - 793us/step
# Epoch 40/150
# 614/614 - 1s - loss: 0.0054 - 501ms/epoch - 816us/step
# Epoch 41/150
# 614/614 - 0s - loss: 0.0055 - 491ms/epoch - 799us/step
# Epoch 42/150
# 614/614 - 0s - loss: 0.0055 - 497ms/epoch - 810us/step
# Epoch 43/150
# 614/614 - 1s - loss: 0.0054 - 502ms/epoch - 818us/step
# Epoch 44/150
# 614/614 - 1s - loss: 0.0055 - 505ms/epoch - 823us/step
# Epoch 45/150
# 614/614 - 0s - loss: 0.0055 - 496ms/epoch - 807us/step
# Epoch 46/150
# 614/614 - 1s - loss: 0.0055 - 502ms/epoch - 818us/step
# Epoch 47/150
# 614/614 - 1s - loss: 0.0054 - 500ms/epoch - 814us/step
# Epoch 48/150
# 614/614 - 1s - loss: 0.0055 - 526ms/epoch - 857us/step
# Epoch 49/150
# 614/614 - 1s - loss: 0.0054 - 533ms/epoch - 869us/step
# Epoch 50/150
# 614/614 - 1s - loss: 0.0055 - 508ms/epoch - 828us/step
# Epoch 51/150
# 614/614 - 1s - loss: 0.0055 - 539ms/epoch - 877us/step
# Epoch 52/150
# 614/614 - 1s - loss: 0.0055 - 648ms/epoch - 1ms/step
# Epoch 53/150
# 614/614 - 1s - loss: 0.0055 - 518ms/epoch - 844us/step
# Epoch 54/150
# 614/614 - 1s - loss: 0.0054 - 520ms/epoch - 847us/step
# Epoch 55/150
# 614/614 - 1s - loss: 0.0054 - 501ms/epoch - 816us/step
# Epoch 56/150
# 614/614 - 1s - loss: 0.0054 - 509ms/epoch - 830us/step
# Epoch 57/150
# 614/614 - 1s - loss: 0.0054 - 501ms/epoch - 816us/step
# Epoch 58/150
# 614/614 - 1s - loss: 0.0055 - 501ms/epoch - 816us/step
# Epoch 59/150
# 614/614 - 1s - loss: 0.0055 - 503ms/epoch - 820us/step
# Epoch 60/150
# 614/614 - 1s - loss: 0.0054 - 500ms/epoch - 815us/step
# Epoch 61/150
# 614/614 - 1s - loss: 0.0054 - 510ms/epoch - 831us/step
# Epoch 62/150
# 614/614 - 1s - loss: 0.0054 - 504ms/epoch - 821us/step
# Epoch 63/150
# 614/614 - 1s - loss: 0.0054 - 506ms/epoch - 824us/step
# Epoch 64/150
# 614/614 - 1s - loss: 0.0055 - 507ms/epoch - 825us/step
# Epoch 65/150
# 614/614 - 1s - loss: 0.0054 - 502ms/epoch - 818us/step
# Epoch 66/150
# 614/614 - 1s - loss: 0.0054 - 502ms/epoch - 818us/step
# Epoch 67/150
# 614/614 - 1s - loss: 0.0054 - 516ms/epoch - 840us/step
# Epoch 68/150
# 614/614 - 1s - loss: 0.0054 - 503ms/epoch - 819us/step
# Epoch 69/150
# 614/614 - 1s - loss: 0.0054 - 520ms/epoch - 847us/step
# Epoch 70/150
# 614/614 - 1s - loss: 0.0055 - 518ms/epoch - 844us/step
# Epoch 71/150
# 614/614 - 1s - loss: 0.0054 - 519ms/epoch - 845us/step
# Epoch 72/150
# 614/614 - 1s - loss: 0.0054 - 507ms/epoch - 825us/step
# Epoch 73/150
# 614/614 - 1s - loss: 0.0054 - 567ms/epoch - 923us/step
# Epoch 74/150
# 614/614 - 1s - loss: 0.0054 - 534ms/epoch - 869us/step
# Epoch 75/150
# 614/614 - 1s - loss: 0.0054 - 543ms/epoch - 885us/step
# Epoch 76/150
# 614/614 - 1s - loss: 0.0054 - 517ms/epoch - 842us/step
# Epoch 77/150
# 614/614 - 1s - loss: 0.0054 - 500ms/epoch - 815us/step
# Epoch 78/150
# 614/614 - 1s - loss: 0.0054 - 500ms/epoch - 814us/step
# Epoch 79/150
# 614/614 - 1s - loss: 0.0054 - 519ms/epoch - 846us/step
# Epoch 80/150
# 614/614 - 1s - loss: 0.0055 - 542ms/epoch - 883us/step
# Epoch 81/150
# 614/614 - 1s - loss: 0.0054 - 508ms/epoch - 828us/step
# Epoch 82/150
# 614/614 - 1s - loss: 0.0054 - 509ms/epoch - 829us/step
# Epoch 83/150
# 614/614 - 1s - loss: 0.0055 - 514ms/epoch - 837us/step
# Epoch 84/150
# 614/614 - 1s - loss: 0.0054 - 504ms/epoch - 821us/step
# Epoch 85/150
# 614/614 - 1s - loss: 0.0054 - 514ms/epoch - 836us/step
# Epoch 86/150
# 614/614 - 1s - loss: 0.0054 - 510ms/epoch - 831us/step
# Epoch 87/150
# 614/614 - 1s - loss: 0.0055 - 570ms/epoch - 929us/step
# Epoch 88/150
# 614/614 - 1s - loss: 0.0054 - 532ms/epoch - 867us/step
# Epoch 89/150
# 614/614 - 1s - loss: 0.0055 - 528ms/epoch - 860us/step
# Epoch 90/150
# 614/614 - 1s - loss: 0.0054 - 512ms/epoch - 835us/step
# Epoch 91/150
# 614/614 - 1s - loss: 0.0054 - 545ms/epoch - 888us/step
# Epoch 92/150
# 614/614 - 1s - loss: 0.0054 - 529ms/epoch - 861us/step
# Epoch 93/150
# 614/614 - 1s - loss: 0.0054 - 514ms/epoch - 838us/step
# Epoch 94/150
# 614/614 - 1s - loss: 0.0055 - 530ms/epoch - 862us/step
# Epoch 95/150
# 614/614 - 1s - loss: 0.0054 - 574ms/epoch - 935us/step
# Epoch 96/150
# 614/614 - 1s - loss: 0.0054 - 559ms/epoch - 910us/step
# Epoch 97/150
# 614/614 - 1s - loss: 0.0054 - 675ms/epoch - 1ms/step
# Epoch 98/150
# 614/614 - 1s - loss: 0.0054 - 611ms/epoch - 995us/step
# Epoch 99/150
# 614/614 - 1s - loss: 0.0054 - 559ms/epoch - 910us/step
# Epoch 100/150
# 614/614 - 1s - loss: 0.0054 - 550ms/epoch - 895us/step
# Epoch 101/150
# 614/614 - 1s - loss: 0.0054 - 635ms/epoch - 1ms/step
# Epoch 102/150
# 614/614 - 1s - loss: 0.0055 - 602ms/epoch - 980us/step
# Epoch 103/150
# 614/614 - 1s - loss: 0.0054 - 555ms/epoch - 903us/step
# Epoch 104/150
# 614/614 - 1s - loss: 0.0055 - 574ms/epoch - 936us/step
# Epoch 105/150
# 614/614 - 1s - loss: 0.0054 - 566ms/epoch - 921us/step
# Epoch 106/150
# 614/614 - 1s - loss: 0.0055 - 630ms/epoch - 1ms/step
# Epoch 107/150
# 614/614 - 1s - loss: 0.0054 - 558ms/epoch - 908us/step
# Epoch 108/150
# 614/614 - 1s - loss: 0.0054 - 588ms/epoch - 958us/step
# Epoch 109/150
# 614/614 - 1s - loss: 0.0054 - 565ms/epoch - 921us/step
# Epoch 110/150
# 614/614 - 1s - loss: 0.0054 - 573ms/epoch - 934us/step
# Epoch 111/150
# 614/614 - 1s - loss: 0.0054 - 611ms/epoch - 996us/step
# Epoch 112/150
# 614/614 - 1s - loss: 0.0054 - 551ms/epoch - 897us/step
# Epoch 113/150
# 614/614 - 1s - loss: 0.0054 - 554ms/epoch - 902us/step
# Epoch 114/150
# 614/614 - 1s - loss: 0.0054 - 503ms/epoch - 819us/step
# Epoch 115/150
# 614/614 - 1s - loss: 0.0054 - 579ms/epoch - 942us/step
# Epoch 116/150
# 614/614 - 1s - loss: 0.0054 - 549ms/epoch - 895us/step
# Epoch 117/150
# 614/614 - 1s - loss: 0.0054 - 532ms/epoch - 867us/step
# Epoch 118/150
# 614/614 - 0s - loss: 0.0054 - 496ms/epoch - 807us/step
# Epoch 119/150
# 614/614 - 1s - loss: 0.0054 - 529ms/epoch - 861us/step
# Epoch 120/150
# 614/614 - 1s - loss: 0.0054 - 528ms/epoch - 860us/step
# Epoch 121/150
# 614/614 - 0s - loss: 0.0055 - 496ms/epoch - 807us/step
# Epoch 122/150
# 614/614 - 1s - loss: 0.0054 - 506ms/epoch - 824us/step
# Epoch 123/150
# 614/614 - 1s - loss: 0.0054 - 557ms/epoch - 907us/step
# Epoch 124/150
# 614/614 - 1s - loss: 0.0055 - 515ms/epoch - 838us/step
# Epoch 125/150
# 614/614 - 1s - loss: 0.0054 - 514ms/epoch - 838us/step
# Epoch 126/150
# 614/614 - 1s - loss: 0.0054 - 580ms/epoch - 944us/step
# Epoch 127/150
# 614/614 - 1s - loss: 0.0054 - 551ms/epoch - 897us/step
# Epoch 128/150
# 614/614 - 1s - loss: 0.0054 - 560ms/epoch - 913us/step
# Epoch 129/150
# 614/614 - 1s - loss: 0.0055 - 555ms/epoch - 903us/step
# Epoch 130/150
# 614/614 - 1s - loss: 0.0054 - 607ms/epoch - 989us/step
# Epoch 131/150
# 614/614 - 1s - loss: 0.0054 - 545ms/epoch - 887us/step
# Epoch 132/150
# 614/614 - 1s - loss: 0.0054 - 525ms/epoch - 855us/step
# Epoch 133/150
# 614/614 - 1s - loss: 0.0054 - 521ms/epoch - 848us/step
# Epoch 134/150
# 614/614 - 1s - loss: 0.0054 - 501ms/epoch - 816us/step
# Epoch 135/150
# 614/614 - 1s - loss: 0.0054 - 505ms/epoch - 823us/step
# Epoch 136/150
# 614/614 - 1s - loss: 0.0054 - 549ms/epoch - 894us/step
# Epoch 137/150
# 614/614 - 1s - loss: 0.0054 - 524ms/epoch - 854us/step
# Epoch 138/150
# 614/614 - 1s - loss: 0.0055 - 510ms/epoch - 831us/step
# Epoch 139/150
# 614/614 - 1s - loss: 0.0054 - 613ms/epoch - 998us/step
# Epoch 140/150
# 614/614 - 1s - loss: 0.0055 - 647ms/epoch - 1ms/step
# Epoch 141/150
# 614/614 - 1s - loss: 0.0054 - 732ms/epoch - 1ms/step
# Epoch 142/150
# 614/614 - 1s - loss: 0.0054 - 680ms/epoch - 1ms/step
# Epoch 143/150
# 614/614 - 1s - loss: 0.0055 - 573ms/epoch - 933us/step
# Epoch 144/150
# 614/614 - 1s - loss: 0.0055 - 518ms/epoch - 844us/step
# Epoch 145/150
# 614/614 - 1s - loss: 0.0054 - 512ms/epoch - 834us/step
# Epoch 146/150
# 614/614 - 1s - loss: 0.0054 - 502ms/epoch - 817us/step
# Epoch 147/150
# 614/614 - 1s - loss: 0.0054 - 614ms/epoch - 1ms/step
# Epoch 148/150
# 614/614 - 1s - loss: 0.0054 - 543ms/epoch - 885us/step
# Epoch 149/150
# 614/614 - 1s - loss: 0.0055 - 585ms/epoch - 952us/step
# Epoch 150/150
# 614/614 - 1s - loss: 0.0054 - 777ms/epoch - 1ms/step

# %%
#make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
#invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
#calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 20/20 [==============================] - 0s 840us/step
# 9/9 [==============================] - 0s 873us/step
# Train Score: 8116995.69 RMSE
# Test Score: 9901904.57 RMSE

# %%
# shift train predictions for plotting
from turtle import color
figure(figsize=(15, 6), dpi=100)
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.title('Original Data vs Prediction for LSTM')
plt.plot(scaler.inverse_transform(dataset))
#plt.plot(trainPredictPlot, color='red')
plt.plot(testPredictPlot, color='orange')
plt.show()
