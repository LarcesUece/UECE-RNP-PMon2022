# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 6), dpi=100)
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
plt.plot(dataset)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
#fix random seed for reproducibility
tf.random.set_seed(7)

# %%
#load the dataset
dataframe = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
#normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
#30,70
#50,50
#70,30
# Out:
# 616 264

# %%
#convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
#reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
#reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
#create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=150, batch_size=1, verbose=2)
# Out:
# Epoch 1/150
# 614/614 - 1s - loss: 0.0389 - 1s/epoch - 2ms/step
# Epoch 2/150
# 614/614 - 0s - loss: 0.0055 - 458ms/epoch - 746us/step
# Epoch 3/150
# 614/614 - 0s - loss: 0.0054 - 451ms/epoch - 735us/step
# Epoch 4/150
# 614/614 - 0s - loss: 0.0054 - 452ms/epoch - 736us/step
# Epoch 5/150
# 614/614 - 0s - loss: 0.0054 - 437ms/epoch - 711us/step
# Epoch 6/150
# 614/614 - 0s - loss: 0.0055 - 433ms/epoch - 705us/step
# Epoch 7/150
# 614/614 - 0s - loss: 0.0055 - 429ms/epoch - 699us/step
# Epoch 8/150
# 614/614 - 0s - loss: 0.0055 - 438ms/epoch - 713us/step
# Epoch 9/150
# 614/614 - 0s - loss: 0.0054 - 438ms/epoch - 713us/step
# Epoch 10/150
# 614/614 - 0s - loss: 0.0054 - 440ms/epoch - 717us/step
# Epoch 11/150
# 614/614 - 0s - loss: 0.0055 - 435ms/epoch - 709us/step
# Epoch 12/150
# 614/614 - 0s - loss: 0.0054 - 457ms/epoch - 744us/step
# Epoch 13/150
# 614/614 - 0s - loss: 0.0054 - 435ms/epoch - 708us/step
# Epoch 14/150
# 614/614 - 0s - loss: 0.0055 - 432ms/epoch - 704us/step
# Epoch 15/150
# 614/614 - 0s - loss: 0.0054 - 463ms/epoch - 755us/step
# Epoch 16/150
# 614/614 - 0s - loss: 0.0054 - 466ms/epoch - 760us/step
# Epoch 17/150
# 614/614 - 0s - loss: 0.0054 - 455ms/epoch - 742us/step
# Epoch 18/150
# 614/614 - 0s - loss: 0.0055 - 447ms/epoch - 728us/step
# Epoch 19/150
# 614/614 - 0s - loss: 0.0054 - 432ms/epoch - 704us/step
# Epoch 20/150
# 614/614 - 0s - loss: 0.0054 - 428ms/epoch - 698us/step
# Epoch 21/150
# 614/614 - 0s - loss: 0.0054 - 438ms/epoch - 713us/step
# Epoch 22/150
# 614/614 - 0s - loss: 0.0054 - 426ms/epoch - 694us/step
# Epoch 23/150
# 614/614 - 1s - loss: 0.0055 - 532ms/epoch - 866us/step
# Epoch 24/150
# 614/614 - 1s - loss: 0.0055 - 563ms/epoch - 917us/step
# Epoch 25/150
# 614/614 - 1s - loss: 0.0054 - 591ms/epoch - 962us/step
# Epoch 26/150
# 614/614 - 1s - loss: 0.0054 - 568ms/epoch - 926us/step
# Epoch 27/150
# 614/614 - 1s - loss: 0.0055 - 560ms/epoch - 912us/step
# Epoch 28/150
# 614/614 - 1s - loss: 0.0054 - 579ms/epoch - 943us/step
# Epoch 29/150
# 614/614 - 1s - loss: 0.0054 - 612ms/epoch - 996us/step
# Epoch 30/150
# 614/614 - 1s - loss: 0.0054 - 567ms/epoch - 924us/step
# Epoch 31/150
# 614/614 - 1s - loss: 0.0055 - 556ms/epoch - 905us/step
# Epoch 32/150
# 614/614 - 1s - loss: 0.0054 - 562ms/epoch - 915us/step
# Epoch 33/150
# 614/614 - 1s - loss: 0.0054 - 567ms/epoch - 923us/step
# Epoch 34/150
# 614/614 - 1s - loss: 0.0054 - 574ms/epoch - 935us/step
# Epoch 35/150
# 614/614 - 1s - loss: 0.0055 - 578ms/epoch - 942us/step
# Epoch 36/150
# 614/614 - 1s - loss: 0.0055 - 564ms/epoch - 919us/step
# Epoch 37/150
# 614/614 - 1s - loss: 0.0055 - 574ms/epoch - 936us/step
# Epoch 38/150
# 614/614 - 1s - loss: 0.0055 - 575ms/epoch - 937us/step
# Epoch 39/150
# 614/614 - 1s - loss: 0.0054 - 556ms/epoch - 906us/step
# Epoch 40/150
# 614/614 - 1s - loss: 0.0054 - 581ms/epoch - 947us/step
# Epoch 41/150
# 614/614 - 1s - loss: 0.0055 - 543ms/epoch - 885us/step
# Epoch 42/150
# 614/614 - 1s - loss: 0.0055 - 570ms/epoch - 928us/step
# Epoch 43/150
# 614/614 - 1s - loss: 0.0054 - 549ms/epoch - 894us/step
# Epoch 44/150
# 614/614 - 1s - loss: 0.0055 - 557ms/epoch - 907us/step
# Epoch 45/150
# 614/614 - 1s - loss: 0.0055 - 563ms/epoch - 917us/step
# Epoch 46/150
# 614/614 - 1s - loss: 0.0055 - 570ms/epoch - 929us/step
# Epoch 47/150
# 614/614 - 1s - loss: 0.0054 - 580ms/epoch - 944us/step
# Epoch 48/150
# 614/614 - 0s - loss: 0.0055 - 464ms/epoch - 756us/step
# Epoch 49/150
# 614/614 - 0s - loss: 0.0054 - 444ms/epoch - 723us/step
# Epoch 50/150
# 614/614 - 0s - loss: 0.0055 - 454ms/epoch - 739us/step
# Epoch 51/150
# 614/614 - 0s - loss: 0.0055 - 428ms/epoch - 697us/step
# Epoch 52/150
# 614/614 - 0s - loss: 0.0055 - 463ms/epoch - 755us/step
# Epoch 53/150
# 614/614 - 0s - loss: 0.0055 - 478ms/epoch - 779us/step
# Epoch 54/150
# 614/614 - 1s - loss: 0.0054 - 587ms/epoch - 957us/step
# Epoch 55/150
# 614/614 - 0s - loss: 0.0054 - 488ms/epoch - 795us/step
# Epoch 56/150
# 614/614 - 0s - loss: 0.0054 - 477ms/epoch - 777us/step
# Epoch 57/150
# 614/614 - 1s - loss: 0.0054 - 510ms/epoch - 830us/step
# Epoch 58/150
# 614/614 - 1s - loss: 0.0054 - 576ms/epoch - 939us/step
# Epoch 59/150
# 614/614 - 1s - loss: 0.0054 - 574ms/epoch - 935us/step
# Epoch 60/150
# 614/614 - 1s - loss: 0.0054 - 573ms/epoch - 933us/step
# Epoch 61/150
# 614/614 - 1s - loss: 0.0054 - 585ms/epoch - 952us/step
# Epoch 62/150
# 614/614 - 1s - loss: 0.0054 - 578ms/epoch - 942us/step
# Epoch 63/150
# 614/614 - 1s - loss: 0.0054 - 569ms/epoch - 927us/step
# Epoch 64/150
# 614/614 - 1s - loss: 0.0055 - 587ms/epoch - 955us/step
# Epoch 65/150
# 614/614 - 1s - loss: 0.0054 - 594ms/epoch - 967us/step
# Epoch 66/150
# 614/614 - 1s - loss: 0.0054 - 589ms/epoch - 960us/step
# Epoch 67/150
# 614/614 - 1s - loss: 0.0054 - 578ms/epoch - 942us/step
# Epoch 68/150
# 614/614 - 1s - loss: 0.0054 - 584ms/epoch - 951us/step
# Epoch 69/150
# 614/614 - 1s - loss: 0.0054 - 573ms/epoch - 934us/step
# Epoch 70/150
# 614/614 - 1s - loss: 0.0054 - 586ms/epoch - 954us/step
# Epoch 71/150
# 614/614 - 1s - loss: 0.0054 - 615ms/epoch - 1ms/step
# Epoch 72/150
# 614/614 - 1s - loss: 0.0054 - 578ms/epoch - 941us/step
# Epoch 73/150
# 614/614 - 1s - loss: 0.0054 - 586ms/epoch - 954us/step
# Epoch 74/150
# 614/614 - 1s - loss: 0.0054 - 586ms/epoch - 955us/step
# Epoch 75/150
# 614/614 - 1s - loss: 0.0054 - 639ms/epoch - 1ms/step
# Epoch 76/150
# 614/614 - 1s - loss: 0.0054 - 645ms/epoch - 1ms/step
# Epoch 77/150
# 614/614 - 1s - loss: 0.0054 - 650ms/epoch - 1ms/step
# Epoch 78/150
# 614/614 - 1s - loss: 0.0054 - 668ms/epoch - 1ms/step
# Epoch 79/150
# 614/614 - 1s - loss: 0.0054 - 635ms/epoch - 1ms/step
# Epoch 80/150
# 614/614 - 1s - loss: 0.0055 - 649ms/epoch - 1ms/step
# Epoch 81/150
# 614/614 - 1s - loss: 0.0054 - 651ms/epoch - 1ms/step
# Epoch 82/150
# 614/614 - 1s - loss: 0.0054 - 639ms/epoch - 1ms/step
# Epoch 83/150
# 614/614 - 1s - loss: 0.0055 - 662ms/epoch - 1ms/step
# Epoch 84/150
# 614/614 - 1s - loss: 0.0054 - 674ms/epoch - 1ms/step
# Epoch 85/150
# 614/614 - 1s - loss: 0.0054 - 637ms/epoch - 1ms/step
# Epoch 86/150
# 614/614 - 1s - loss: 0.0054 - 658ms/epoch - 1ms/step
# Epoch 87/150
# 614/614 - 1s - loss: 0.0054 - 645ms/epoch - 1ms/step
# Epoch 88/150
# 614/614 - 1s - loss: 0.0054 - 638ms/epoch - 1ms/step
# Epoch 89/150
# 614/614 - 1s - loss: 0.0055 - 636ms/epoch - 1ms/step
# Epoch 90/150
# 614/614 - 1s - loss: 0.0054 - 648ms/epoch - 1ms/step
# Epoch 91/150
# 614/614 - 1s - loss: 0.0054 - 654ms/epoch - 1ms/step
# Epoch 92/150
# 614/614 - 1s - loss: 0.0054 - 657ms/epoch - 1ms/step
# Epoch 93/150
# 614/614 - 1s - loss: 0.0054 - 643ms/epoch - 1ms/step
# Epoch 94/150
# 614/614 - 1s - loss: 0.0054 - 632ms/epoch - 1ms/step
# Epoch 95/150
# 614/614 - 1s - loss: 0.0054 - 653ms/epoch - 1ms/step
# Epoch 96/150
# 614/614 - 1s - loss: 0.0054 - 653ms/epoch - 1ms/step
# Epoch 97/150
# 614/614 - 1s - loss: 0.0054 - 645ms/epoch - 1ms/step
# Epoch 98/150
# 614/614 - 1s - loss: 0.0054 - 654ms/epoch - 1ms/step
# Epoch 99/150
# 614/614 - 1s - loss: 0.0054 - 667ms/epoch - 1ms/step
# Epoch 100/150
# 614/614 - 1s - loss: 0.0054 - 637ms/epoch - 1ms/step
# Epoch 101/150
# 614/614 - 1s - loss: 0.0054 - 646ms/epoch - 1ms/step
# Epoch 102/150
# 614/614 - 1s - loss: 0.0055 - 659ms/epoch - 1ms/step
# Epoch 103/150
# 614/614 - 1s - loss: 0.0054 - 641ms/epoch - 1ms/step
# Epoch 104/150
# 614/614 - 1s - loss: 0.0055 - 643ms/epoch - 1ms/step
# Epoch 105/150
# 614/614 - 1s - loss: 0.0054 - 637ms/epoch - 1ms/step
# Epoch 106/150
# 614/614 - 1s - loss: 0.0055 - 652ms/epoch - 1ms/step
# Epoch 107/150
# 614/614 - 1s - loss: 0.0054 - 647ms/epoch - 1ms/step
# Epoch 108/150
# 614/614 - 1s - loss: 0.0054 - 641ms/epoch - 1ms/step
# Epoch 109/150
# 614/614 - 1s - loss: 0.0054 - 647ms/epoch - 1ms/step
# Epoch 110/150
# 614/614 - 1s - loss: 0.0054 - 653ms/epoch - 1ms/step
# Epoch 111/150
# 614/614 - 1s - loss: 0.0054 - 655ms/epoch - 1ms/step
# Epoch 112/150
# 614/614 - 1s - loss: 0.0054 - 639ms/epoch - 1ms/step
# Epoch 113/150
# 614/614 - 1s - loss: 0.0054 - 645ms/epoch - 1ms/step
# Epoch 114/150
# 614/614 - 1s - loss: 0.0054 - 636ms/epoch - 1ms/step
# Epoch 115/150
# 614/614 - 1s - loss: 0.0054 - 636ms/epoch - 1ms/step
# Epoch 116/150
# 614/614 - 1s - loss: 0.0054 - 635ms/epoch - 1ms/step
# Epoch 117/150
# 614/614 - 1s - loss: 0.0054 - 638ms/epoch - 1ms/step
# Epoch 118/150
# 614/614 - 1s - loss: 0.0054 - 632ms/epoch - 1ms/step
# Epoch 119/150
# 614/614 - 1s - loss: 0.0054 - 638ms/epoch - 1ms/step
# Epoch 120/150
# 614/614 - 1s - loss: 0.0054 - 640ms/epoch - 1ms/step
# Epoch 121/150
# 614/614 - 1s - loss: 0.0055 - 664ms/epoch - 1ms/step
# Epoch 122/150
# 614/614 - 1s - loss: 0.0054 - 652ms/epoch - 1ms/step
# Epoch 123/150
# 614/614 - 1s - loss: 0.0054 - 663ms/epoch - 1ms/step
# Epoch 124/150
# 614/614 - 1s - loss: 0.0055 - 658ms/epoch - 1ms/step
# Epoch 125/150
# 614/614 - 1s - loss: 0.0054 - 633ms/epoch - 1ms/step
# Epoch 126/150
# 614/614 - 1s - loss: 0.0054 - 640ms/epoch - 1ms/step
# Epoch 127/150
# 614/614 - 1s - loss: 0.0054 - 665ms/epoch - 1ms/step
# Epoch 128/150
# 614/614 - 1s - loss: 0.0054 - 635ms/epoch - 1ms/step
# Epoch 129/150
# 614/614 - 1s - loss: 0.0055 - 642ms/epoch - 1ms/step
# Epoch 130/150
# 614/614 - 1s - loss: 0.0054 - 652ms/epoch - 1ms/step
# Epoch 131/150
# 614/614 - 1s - loss: 0.0054 - 648ms/epoch - 1ms/step
# Epoch 132/150
# 614/614 - 1s - loss: 0.0054 - 667ms/epoch - 1ms/step
# Epoch 133/150
# 614/614 - 1s - loss: 0.0054 - 658ms/epoch - 1ms/step
# Epoch 134/150
# 614/614 - 1s - loss: 0.0054 - 647ms/epoch - 1ms/step
# Epoch 135/150
# 614/614 - 1s - loss: 0.0054 - 646ms/epoch - 1ms/step
# Epoch 136/150
# 614/614 - 1s - loss: 0.0054 - 647ms/epoch - 1ms/step
# Epoch 137/150
# 614/614 - 1s - loss: 0.0054 - 643ms/epoch - 1ms/step
# Epoch 138/150
# 614/614 - 1s - loss: 0.0055 - 644ms/epoch - 1ms/step
# Epoch 139/150
# 614/614 - 1s - loss: 0.0054 - 643ms/epoch - 1ms/step
# Epoch 140/150
# 614/614 - 1s - loss: 0.0055 - 651ms/epoch - 1ms/step
# Epoch 141/150
# 614/614 - 1s - loss: 0.0054 - 652ms/epoch - 1ms/step
# Epoch 142/150
# 614/614 - 1s - loss: 0.0054 - 645ms/epoch - 1ms/step
# Epoch 143/150
# 614/614 - 1s - loss: 0.0055 - 634ms/epoch - 1ms/step
# Epoch 144/150
# 614/614 - 1s - loss: 0.0055 - 671ms/epoch - 1ms/step
# Epoch 145/150
# 614/614 - 1s - loss: 0.0054 - 676ms/epoch - 1ms/step
# Epoch 146/150
# 614/614 - 1s - loss: 0.0054 - 684ms/epoch - 1ms/step
# Epoch 147/150
# 614/614 - 1s - loss: 0.0054 - 686ms/epoch - 1ms/step
# Epoch 148/150
# 614/614 - 1s - loss: 0.0054 - 684ms/epoch - 1ms/step
# Epoch 149/150
# 614/614 - 1s - loss: 0.0055 - 688ms/epoch - 1ms/step
# Epoch 150/150
# 614/614 - 1s - loss: 0.0054 - 685ms/epoch - 1ms/step

# %%
#make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
#invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
#calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 20/20 [==============================] - 0s 981us/step
# 9/9 [==============================] - 0s 1ms/step
# Train Score: 8114866.74 RMSE
# Test Score: 9896638.22 RMSE

# %%
# shift train predictions for plotting
from turtle import color
figure(figsize=(15, 6), dpi=100)
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.title('Original Data vs Prediction for LSTM')
plt.plot(scaler.inverse_transform(dataset))
#plt.plot(trainPredictPlot, color='red')
plt.plot(testPredictPlot, color='orange')
plt.show()

# %%
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction

prediction_gru = prediction(model_gru)
#prediction_bilstm = prediction(model_bilstm)

# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    
    plt.figure(figsize=(15, 6))
    
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), label='Original')
    plt.plot(np.arange(range_future), np.array(prediction),label='Prediction')

    plt.title(' Original data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    #plt.ylabel('Daily water consumption ($m^3$/capita.day)')
       
plot_future(prediction_gru, 'GRU', y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 7
#       4     prediction = scaler.inverse_transform(prediction)
#       5     return prediction
# ----> 7 prediction_gru = prediction(model_gru)
#       8 #prediction_bilstm = prediction(model_bilstm)
#       9
#      10 # Plot test data vs prediction
#      11 def plot_future(prediction, model_name, y_test):
#
# NameError: name 'model_gru' is not defined

# %%
from turtle import color


plt.plot(trainPredictPlot, color='green')

# %%
from turtle import color


plt.plot(testPredictPlot, color='red')
