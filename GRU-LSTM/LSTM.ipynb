# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from matplotlib.pyplot import figure
figure(figsize=(15, 6), dpi=100)
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
plt.plot(dataset)
plt.show()

# %%
#fix random seed for reproducibility
tf.random.set_seed(7)

# %%
#load the dataset
dataframe = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
#normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
#30,70
#50,50
#70,30
# Out:
# 616 264

# %%
#convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
#reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
#reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
#create and fit the LSTM network
model = Sequential()
model.add(LSTM(64, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss ='mean_squared_error', optimizer ='adam')
model.fit(trainX, trainY, epochs = 150, validation_split = 0.2, batch_size = 26, shuffle = False)
# Out:
# Epoch 1/150
# 19/19 [==============================] - 2s 20ms/step - loss: 0.2797 - val_loss: 0.2030
# Epoch 2/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1740 - val_loss: 0.1150
# Epoch 3/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0898 - val_loss: 0.0505
# Epoch 4/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0336 - val_loss: 0.0167
# Epoch 5/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0088
# Epoch 6/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0091
# Epoch 7/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0091
# Epoch 8/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 9/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 10/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 11/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 12/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 13/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 14/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 15/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 16/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 17/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 18/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 19/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 20/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 21/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 22/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 23/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 24/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 25/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 26/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 27/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 28/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 29/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 30/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 31/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 32/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 33/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 34/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 35/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 36/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 37/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 38/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 39/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 40/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 41/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 42/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 43/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 44/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 45/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 46/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 47/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 48/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 49/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 50/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 51/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 52/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 53/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 54/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 55/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 56/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 57/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 58/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 59/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 60/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 61/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 62/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 63/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 64/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 65/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 66/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 67/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 68/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 69/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 70/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 71/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 72/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 73/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 74/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 75/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 76/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 77/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 78/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 79/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 80/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 81/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 82/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 83/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 84/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 85/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 86/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 87/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 88/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 89/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 90/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 91/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 92/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 93/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 94/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 95/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 96/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 97/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 98/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 99/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 100/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 101/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 102/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 103/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 104/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 105/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 106/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 107/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 108/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 109/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 110/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 111/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 112/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 113/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 114/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 115/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 116/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 117/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 118/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 119/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 120/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 121/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 122/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 123/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 124/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 125/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 126/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 127/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 128/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 129/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 130/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 131/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 132/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 133/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 134/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 135/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 136/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 137/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 138/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 139/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 140/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 141/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 142/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 143/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 144/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 145/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 146/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 147/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 148/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 149/150
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 150/150
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089

# %%
#make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
#invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
#calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 20/20 [==============================] - 0s 925us/step
# 9/9 [==============================] - 0s 1ms/step
# Train Score: 8113537.03 RMSE
# Test Score: 9919644.24 RMSE

# %%
# shift train predictions for plotting
from turtle import color
figure(figsize=(15, 6), dpi=100)
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.title('Original Data vs Prediction for LSTM')
plt.plot(scaler.inverse_transform(dataset))
#plt.plot(trainPredictPlot, color='red')
plt.plot(testPredictPlot, color='orange')
plt.show()
