# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy import stats
# %matplotlib inline
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU
from matplotlib.pyplot import figure

figure(figsize=(15, 6), dpi=100)
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')
plt.plot(dataset)
plt.show()

# %%
# Set random seed to get the same result after each time running the code
tf.random.set_seed(7)

# %%
file = 'bbr esmond data 08-25-2022.csv'
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados\bbr esmond data_sem_outliers 10-18-2022.csv', usecols=[0], engine='python')

# %%
#normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# Split train data and test data
train_size = int(len(dataset)*0.7)

# train_data = df.WC.loc[:train_size] -----> it gives a series
# Do not forget use iloc to select a number of rows
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# %%
# Scale data
# The input to scaler.fit -> array-like, sparse matrix, dataframe of shape (n_samples, n_features)
scaler = MinMaxScaler().fit(train_data)

train_scaled = scaler.transform(dataset)
test_scaled = scaler.transform(dataset)

# %%
# Create input dataset
# Th input shape should be [samples, time steps, features]
def create_dataset (X, look_back = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
        
    return np.array(Xs), np.array(ys)

X_train, y_train = create_dataset(train_scaled,30)
X_test, y_test = create_dataset(test_scaled,30)

print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
X_test[:33].shape
# Out:
# X_train.shape:  (850, 30, 1)
# y_train.shape:  (850, 1)
# X_test.shape:  (850, 30, 1)
# y_test.shape:  (850, 1)
# (33, 30, 1)

# %%
# Create GRU model
def create_gru(units):
    model = Sequential()
    
    # Input layer 
    model.add(GRU(units = units, return_sequences = True, input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    
    # Hidden layer
    model.add(GRU(units = units))                 
    model.add(Dropout(0.2))
    model.add(Dense(1))
    
    #Compile model
    model.compile(optimizer='adam',loss='mse')
   
    return model
model_gru = create_gru(64)

# Create LSTM model
def create_lstm(units):
    model = Sequential()
    
    # Input layer
    model.add(LSTM(units = units, return_sequences = True, input_shape = [X_train.shape[1], X_train.shape[2]]))
    
    # Hidden layer
    model.add(LSTM(units = units))
    model.add(Dense(1))
    
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    
    return model
model_lstm = create_lstm(64)

def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10)
    history = model.fit(X_train, y_train, epochs = 150, validation_split = 0.2, batch_size = 26, shuffle = False)
    return history

history_gru = fit_model(model_gru)
history_lstm = fit_model(model_lstm)
# Out:
# Epoch 1/150
# 27/27 [==============================] - 4s 40ms/step - loss: 0.0645 - val_loss: 0.0125
# Epoch 2/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0207 - val_loss: 0.0124
# Epoch 3/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0187 - val_loss: 0.0122
# Epoch 4/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0185 - val_loss: 0.0122
# Epoch 5/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0170 - val_loss: 0.0120
# Epoch 6/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0168 - val_loss: 0.0120
# Epoch 7/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0119
# Epoch 8/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0167 - val_loss: 0.0119
# Epoch 9/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0159 - val_loss: 0.0122
# Epoch 10/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0162 - val_loss: 0.0120
# Epoch 11/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0149 - val_loss: 0.0120
# Epoch 12/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 0.0126
# Epoch 13/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0162 - val_loss: 0.0128
# Epoch 14/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0154 - val_loss: 0.0122
# Epoch 15/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0145 - val_loss: 0.0123
# Epoch 16/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 0.0124
# Epoch 17/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0149 - val_loss: 0.0124
# Epoch 18/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0136 - val_loss: 0.0125
# Epoch 19/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0140 - val_loss: 0.0125
# Epoch 20/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0136 - val_loss: 0.0128
# Epoch 21/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0139 - val_loss: 0.0125
# Epoch 22/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 23/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 24/150
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0139 - val_loss: 0.0140
# Epoch 25/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0146 - val_loss: 0.0131
# Epoch 26/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0140 - val_loss: 0.0128
# Epoch 27/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0131 - val_loss: 0.0136
# Epoch 28/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0137 - val_loss: 0.0129
# Epoch 29/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0121 - val_loss: 0.0128
# Epoch 30/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0127 - val_loss: 0.0128
# Epoch 31/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0131 - val_loss: 0.0134
# Epoch 32/150
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0132 - val_loss: 0.0128
# Epoch 33/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0128 - val_loss: 0.0134
# Epoch 34/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0134 - val_loss: 0.0131
# Epoch 35/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0129 - val_loss: 0.0132
# Epoch 36/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 37/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0129 - val_loss: 0.0133
# Epoch 38/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0126 - val_loss: 0.0140
# Epoch 39/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 40/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0136 - val_loss: 0.0128
# Epoch 41/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 42/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0125 - val_loss: 0.0132
# Epoch 43/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0127 - val_loss: 0.0134
# Epoch 44/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 45/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0130 - val_loss: 0.0130
# Epoch 46/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0124 - val_loss: 0.0134
# Epoch 47/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 48/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0126 - val_loss: 0.0132
# Epoch 49/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0124 - val_loss: 0.0130
# Epoch 50/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0129 - val_loss: 0.0132
# Epoch 51/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0135 - val_loss: 0.0129
# Epoch 52/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0129 - val_loss: 0.0132
# Epoch 53/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0125 - val_loss: 0.0132
# Epoch 54/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0129 - val_loss: 0.0131
# Epoch 55/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0124 - val_loss: 0.0131
# Epoch 56/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0127 - val_loss: 0.0128
# Epoch 57/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0122 - val_loss: 0.0135
# Epoch 58/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0126 - val_loss: 0.0129
# Epoch 59/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0126 - val_loss: 0.0131
# Epoch 60/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0120 - val_loss: 0.0133
# Epoch 61/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0133
# Epoch 62/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0129
# Epoch 63/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0117 - val_loss: 0.0133
# Epoch 64/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0128
# Epoch 65/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0129
# Epoch 66/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0132
# Epoch 67/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0120 - val_loss: 0.0133
# Epoch 68/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0126 - val_loss: 0.0126
# Epoch 69/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0113 - val_loss: 0.0130
# Epoch 70/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0125 - val_loss: 0.0128
# Epoch 71/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0123 - val_loss: 0.0129
# Epoch 72/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0120 - val_loss: 0.0129
# Epoch 73/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 0.0131
# Epoch 74/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0111 - val_loss: 0.0129
# Epoch 75/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0113 - val_loss: 0.0131
# Epoch 76/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0114 - val_loss: 0.0129
# Epoch 77/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 78/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0118 - val_loss: 0.0132
# Epoch 79/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0121 - val_loss: 0.0128
# Epoch 80/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0117 - val_loss: 0.0129
# Epoch 81/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0112 - val_loss: 0.0129
# Epoch 82/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0111 - val_loss: 0.0132
# Epoch 83/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0115 - val_loss: 0.0131
# Epoch 84/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0120 - val_loss: 0.0128
# Epoch 85/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0110 - val_loss: 0.0131
# Epoch 86/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0136
# Epoch 87/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0111 - val_loss: 0.0133
# Epoch 88/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0114 - val_loss: 0.0129
# Epoch 89/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0114 - val_loss: 0.0131
# Epoch 90/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 0.0132
# Epoch 91/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0114 - val_loss: 0.0127
# Epoch 92/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0115 - val_loss: 0.0132
# Epoch 93/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0113 - val_loss: 0.0127
# Epoch 94/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0112 - val_loss: 0.0130
# Epoch 95/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0117 - val_loss: 0.0125
# Epoch 96/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 97/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0115 - val_loss: 0.0126
# Epoch 98/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 0.0132
# Epoch 99/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 0.0127
# Epoch 100/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0112 - val_loss: 0.0132
# Epoch 101/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0116 - val_loss: 0.0128
# Epoch 102/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0111 - val_loss: 0.0131
# Epoch 103/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0108 - val_loss: 0.0128
# Epoch 104/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0115 - val_loss: 0.0129
# Epoch 105/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0115 - val_loss: 0.0128
# Epoch 106/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0115 - val_loss: 0.0131
# Epoch 107/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0113 - val_loss: 0.0126
# Epoch 108/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0113 - val_loss: 0.0127
# Epoch 109/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0116 - val_loss: 0.0126
# Epoch 110/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0106 - val_loss: 0.0128
# Epoch 111/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0107 - val_loss: 0.0129
# Epoch 112/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0108 - val_loss: 0.0127
# Epoch 113/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0108 - val_loss: 0.0127
# Epoch 114/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0110 - val_loss: 0.0128
# Epoch 115/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0114 - val_loss: 0.0126
# Epoch 116/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0106 - val_loss: 0.0130
# Epoch 117/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0113 - val_loss: 0.0128
# Epoch 118/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 0.0127
# Epoch 119/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0110 - val_loss: 0.0128
# Epoch 120/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 0.0131
# Epoch 121/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0105 - val_loss: 0.0127
# Epoch 122/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0110 - val_loss: 0.0126
# Epoch 123/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0107 - val_loss: 0.0128
# Epoch 124/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 0.0128
# Epoch 125/150
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0106 - val_loss: 0.0128
# Epoch 126/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0110 - val_loss: 0.0128
# Epoch 127/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0104 - val_loss: 0.0129
# Epoch 128/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0112 - val_loss: 0.0128
# Epoch 129/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0105 - val_loss: 0.0127
# Epoch 130/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0110 - val_loss: 0.0127
# Epoch 131/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 0.0128
# Epoch 132/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0107 - val_loss: 0.0129
# Epoch 133/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0110 - val_loss: 0.0128
# Epoch 134/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 0.0131
# Epoch 135/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0105 - val_loss: 0.0127
# Epoch 136/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0112 - val_loss: 0.0128
# Epoch 137/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0110 - val_loss: 0.0127
# Epoch 138/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0108 - val_loss: 0.0128
# Epoch 139/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0107 - val_loss: 0.0126
# Epoch 140/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0107 - val_loss: 0.0128
# Epoch 141/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0102 - val_loss: 0.0129
# Epoch 142/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0105 - val_loss: 0.0132
# Epoch 143/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 144/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0108 - val_loss: 0.0124
# Epoch 145/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0103 - val_loss: 0.0128
# Epoch 146/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0105 - val_loss: 0.0128
# Epoch 147/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0104 - val_loss: 0.0129
# Epoch 148/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 0.0132
# Epoch 149/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0108 - val_loss: 0.0128
# Epoch 150/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0105 - val_loss: 0.0133
# Epoch 1/150
# 27/27 [==============================] - 3s 39ms/step - loss: 0.0806 - val_loss: 0.0211
# Epoch 2/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0188 - val_loss: 0.0130
# Epoch 3/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0170 - val_loss: 0.0129
# Epoch 4/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0171 - val_loss: 0.0129
# Epoch 5/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0169 - val_loss: 0.0128
# Epoch 6/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0169 - val_loss: 0.0127
# Epoch 7/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0167 - val_loss: 0.0126
# Epoch 8/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0166 - val_loss: 0.0126
# Epoch 9/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0165 - val_loss: 0.0125
# Epoch 10/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0163 - val_loss: 0.0124
# Epoch 11/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0162 - val_loss: 0.0123
# Epoch 12/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0159 - val_loss: 0.0123
# Epoch 13/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0157 - val_loss: 0.0122
# Epoch 14/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0154 - val_loss: 0.0121
# Epoch 15/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0151 - val_loss: 0.0119
# Epoch 16/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0148 - val_loss: 0.0118
# Epoch 17/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0144 - val_loss: 0.0117
# Epoch 18/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0140 - val_loss: 0.0116
# Epoch 19/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0135 - val_loss: 0.0115
# Epoch 20/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0130 - val_loss: 0.0114
# Epoch 21/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0126 - val_loss: 0.0116
# Epoch 22/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0124 - val_loss: 0.0117
# Epoch 23/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0123 - val_loss: 0.0118
# Epoch 24/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0121 - val_loss: 0.0118
# Epoch 25/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0119 - val_loss: 0.0118
# Epoch 26/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0117 - val_loss: 0.0119
# Epoch 27/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 28/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0115 - val_loss: 0.0121
# Epoch 29/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0114 - val_loss: 0.0123
# Epoch 30/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0112 - val_loss: 0.0122
# Epoch 31/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0113 - val_loss: 0.0125
# Epoch 32/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0110 - val_loss: 0.0120
# Epoch 33/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0112 - val_loss: 0.0124
# Epoch 34/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 35/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0105 - val_loss: 0.0127
# Epoch 36/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0106 - val_loss: 0.0123
# Epoch 37/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0105 - val_loss: 0.0128
# Epoch 38/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0105 - val_loss: 0.0127
# Epoch 39/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0105 - val_loss: 0.0129
# Epoch 40/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0105 - val_loss: 0.0128
# Epoch 41/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0104 - val_loss: 0.0130
# Epoch 42/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0104 - val_loss: 0.0130
# Epoch 43/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0103 - val_loss: 0.0131
# Epoch 44/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0103 - val_loss: 0.0131
# Epoch 45/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0103 - val_loss: 0.0130
# Epoch 46/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0102 - val_loss: 0.0132
# Epoch 47/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0102 - val_loss: 0.0130
# Epoch 48/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0101 - val_loss: 0.0132
# Epoch 49/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0101 - val_loss: 0.0132
# Epoch 50/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0101 - val_loss: 0.0131
# Epoch 51/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0100 - val_loss: 0.0131
# Epoch 52/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0101 - val_loss: 0.0132
# Epoch 53/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0101 - val_loss: 0.0130
# Epoch 54/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0100 - val_loss: 0.0136
# Epoch 55/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0099 - val_loss: 0.0131
# Epoch 56/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0099 - val_loss: 0.0133
# Epoch 57/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0099 - val_loss: 0.0133
# Epoch 58/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0099 - val_loss: 0.0132
# Epoch 59/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0098 - val_loss: 0.0136
# Epoch 60/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0099 - val_loss: 0.0133
# Epoch 61/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0099 - val_loss: 0.0132
# Epoch 62/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0098 - val_loss: 0.0137
# Epoch 63/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0098 - val_loss: 0.0134
# Epoch 64/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0098 - val_loss: 0.0134
# Epoch 65/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0098 - val_loss: 0.0137
# Epoch 66/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0100 - val_loss: 0.0134
# Epoch 67/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0098 - val_loss: 0.0135
# Epoch 68/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0098 - val_loss: 0.0134
# Epoch 69/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0134
# Epoch 70/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0097 - val_loss: 0.0132
# Epoch 71/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 72/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0096 - val_loss: 0.0134
# Epoch 73/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0097 - val_loss: 0.0134
# Epoch 74/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0097 - val_loss: 0.0135
# Epoch 75/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 76/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0096 - val_loss: 0.0137
# Epoch 77/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0098 - val_loss: 0.0133
# Epoch 78/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0095 - val_loss: 0.0138
# Epoch 79/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0098 - val_loss: 0.0134
# Epoch 80/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0096 - val_loss: 0.0133
# Epoch 81/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0096 - val_loss: 0.0134
# Epoch 82/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 83/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0098 - val_loss: 0.0132
# Epoch 84/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0136
# Epoch 85/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 86/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0095 - val_loss: 0.0139
# Epoch 87/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0098 - val_loss: 0.0133
# Epoch 88/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0095 - val_loss: 0.0141
# Epoch 89/150
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0097 - val_loss: 0.0134
# Epoch 90/150
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0095 - val_loss: 0.0141
# Epoch 91/150
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0096 - val_loss: 0.0134
# Epoch 92/150
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0094 - val_loss: 0.0139
# Epoch 93/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0094 - val_loss: 0.0135
# Epoch 94/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0094 - val_loss: 0.0139
# Epoch 95/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0094 - val_loss: 0.0135
# Epoch 96/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0094 - val_loss: 0.0140
# Epoch 97/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0095 - val_loss: 0.0134
# Epoch 98/150
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0093 - val_loss: 0.0143
# Epoch 99/150
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0095 - val_loss: 0.0135
# Epoch 100/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0139
# Epoch 101/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0136
# Epoch 102/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 103/150
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0136
# Epoch 104/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0092 - val_loss: 0.0140
# Epoch 105/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0093 - val_loss: 0.0136
# Epoch 106/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0092 - val_loss: 0.0141
# Epoch 107/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0095 - val_loss: 0.0134
# Epoch 108/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0091 - val_loss: 0.0141
# Epoch 109/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0093 - val_loss: 0.0136
# Epoch 110/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0092 - val_loss: 0.0140
# Epoch 111/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0093 - val_loss: 0.0135
# Epoch 112/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0091 - val_loss: 0.0141
# Epoch 113/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0094 - val_loss: 0.0135
# Epoch 114/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0141
# Epoch 115/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 116/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0140
# Epoch 117/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0092 - val_loss: 0.0137
# Epoch 118/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0090 - val_loss: 0.0140
# Epoch 119/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0091 - val_loss: 0.0138
# Epoch 120/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0140
# Epoch 121/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0091 - val_loss: 0.0137
# Epoch 122/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0141
# Epoch 123/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0137
# Epoch 124/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0089 - val_loss: 0.0141
# Epoch 125/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0137
# Epoch 126/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0089 - val_loss: 0.0141
# Epoch 127/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0135
# Epoch 128/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0088 - val_loss: 0.0140
# Epoch 129/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0140
# Epoch 130/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0089 - val_loss: 0.0142
# Epoch 131/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0092 - val_loss: 0.0136
# Epoch 132/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0140
# Epoch 133/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0136
# Epoch 134/150
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0088 - val_loss: 0.0141
# Epoch 135/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0093 - val_loss: 0.0135
# Epoch 136/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0137
# Epoch 137/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0087 - val_loss: 0.0144
# Epoch 138/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 139/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0087 - val_loss: 0.0143
# Epoch 140/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0091 - val_loss: 0.0140
# Epoch 141/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0088 - val_loss: 0.0141
# Epoch 142/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0091 - val_loss: 0.0136
# Epoch 143/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0088 - val_loss: 0.0143
# Epoch 144/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0089 - val_loss: 0.0138
# Epoch 145/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0091 - val_loss: 0.0140
# Epoch 146/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0090 - val_loss: 0.0133
# Epoch 147/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0086 - val_loss: 0.0140
# Epoch 148/150
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0088 - val_loss: 0.0143
# Epoch 149/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0143
# Epoch 150/150
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0134

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (15, 6), dpi=100)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_gru, 'GRU')
plot_loss (history_lstm, 'LSTM')

# Transform data back to original data space
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction

prediction_gru = prediction(model_gru)
prediction_lstm = prediction(model_lstm)

# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    
    plt.figure(figsize=(15, 6), dpi=100)
    
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), label='Test data')
    plt.plot(np.arange(range_future), np.array(prediction), label='Prediction')
    

    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time')
    plt.ylabel('Bits/s')

plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_lstm, 'LSTM', y_test)

# Calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

evaluate_prediction(prediction_gru, y_test, 'GRU')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
# Out:
# 27/27 [==============================] - 1s 6ms/step
# 27/27 [==============================] - 1s 8ms/step
# GRU:
# Mean Absolute Error: 0.0534
# Root Mean Square Error: 0.0791
#
# LSTM:
# Mean Absolute Error: 0.0530
# Root Mean Square Error: 0.0769
