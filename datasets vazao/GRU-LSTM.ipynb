# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from scipy import stats
# %matplotlib inline
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU

from matplotlib.pyplot import figure

figure(figsize = (15, 6), dpi = 100)
dataset = pd.read_csv(r'D:\Git\UECE-RNP-PMon2022\datasets vazao\cubic esmond data pa-ba 10-21-2022.csv', usecols = [1], engine ='python')
plt.plot(dataset)
plt.show()

# %%
# Set random seed to get the same result after each time running the code
tf.random.set_seed(7)

# %%
file = 'bbr esmond data 08-25-2022.csv'
dataset = pd.read_csv(r'D:\Git\UECE-RNP-PMon2022\datasets vazao\cubic esmond data pa-ba 10-21-2022.csv', usecols = [1], engine = 'python')

# %%
# Split train data and test data
train_size = int(len(dataset)*0.7)

# train_data = df.WC.loc[:train_size] -----> it gives a series
# Do not forget use iloc to select a number of rows
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# %%
# Scale data
# The input to scaler.fit -> array-like, sparse matrix, dataframe of shape (n_samples, n_features)
scaler = MinMaxScaler().fit(train_data)

train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
# Create input dataset
# Th input shape should be [samples, time steps, features]
def create_dataset (X, look_back = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
        
    return np.array(Xs), np.array(ys)

X_train, y_train = create_dataset(train_scaled,30)
X_test, y_test = create_dataset(test_scaled,30)

print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
X_test[:33].shape
# Out:
# X_train.shape:  (639, 30, 1)
# y_train.shape:  (639, 1)
# X_test.shape:  (258, 30, 1)
# y_test.shape:  (258, 1)
# (33, 30, 1)

# %%
# Create GRU model
def create_gru(units):
    model = Sequential()
    
    # Input layer 
    model.add(GRU(units = units, return_sequences = True, input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    
    # Hidden layer
    model.add(GRU(units = units))                 
    model.add(Dropout(0.2))
    model.add(Dense(1))
    
    #Compile model
    model.compile(optimizer='adam',loss='mse')
   
    return model
model_gru = create_gru(64)

# Create LSTM model
def create_lstm(units):
    model = Sequential()
    
    # Input layer
    model.add(LSTM(units = units, return_sequences = True, input_shape = [X_train.shape[1], X_train.shape[2]]))
    
    # Hidden layer
    model.add(LSTM(units = units))
    model.add(Dense(1))
    
    #Compile model
    model.compile(optimizer ='adam',loss ='mse')
    
    return model
model_lstm = create_lstm(64)

def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10)
    history = model.fit(X_train, y_train, epochs = 150, validation_split = 0.2, batch_size = 26, shuffle = False)
    return history

history_gru = fit_model(model_gru)
history_lstm = fit_model(model_lstm)
# Out:
# Epoch 1/150
# 20/20 [==============================] - 4s 50ms/step - loss: 0.0352 - val_loss: 0.0139
# Epoch 2/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0080 - val_loss: 0.0131
# Epoch 3/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0133
# Epoch 4/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0132
# Epoch 5/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0045 - val_loss: 0.0135
# Epoch 6/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 0.0137
# Epoch 7/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0036 - val_loss: 0.0139
# Epoch 8/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0140
# Epoch 9/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0142
# Epoch 10/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0142
# Epoch 11/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 0.0140
# Epoch 12/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0140
# Epoch 13/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0142
# Epoch 14/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0141
# Epoch 15/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0144
# Epoch 16/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0036 - val_loss: 0.0140
# Epoch 17/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0142
# Epoch 18/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0143
# Epoch 19/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0140
# Epoch 20/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 21/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0142
# Epoch 22/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0141
# Epoch 23/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 24/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0033 - val_loss: 0.0141
# Epoch 25/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 26/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0140
# Epoch 27/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0140
# Epoch 28/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 29/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0141
# Epoch 30/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0141
# Epoch 31/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0140
# Epoch 32/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 33/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 34/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0141
# Epoch 35/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0143
# Epoch 36/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0143
# Epoch 37/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 38/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0143
# Epoch 39/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0145
# Epoch 40/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0143
# Epoch 41/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 42/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0143
# Epoch 43/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0143
# Epoch 44/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 45/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 46/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0144
# Epoch 47/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0144
# Epoch 48/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0143
# Epoch 49/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 0.0144
# Epoch 50/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0145
# Epoch 51/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0144
# Epoch 52/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0145
# Epoch 53/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0145
# Epoch 54/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0145
# Epoch 55/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0145
# Epoch 56/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 0.0144
# Epoch 57/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0145
# Epoch 58/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 0.0145
# Epoch 59/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0146
# Epoch 60/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0146
# Epoch 61/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0145
# Epoch 62/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0147
# Epoch 63/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0033 - val_loss: 0.0147
# Epoch 64/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0147
# Epoch 65/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0147
# Epoch 66/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0147
# Epoch 67/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0148
# Epoch 68/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0148
# Epoch 69/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0148
# Epoch 70/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0147
# Epoch 71/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0148
# Epoch 72/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0150
# Epoch 73/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0150
# Epoch 74/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 0.0150
# Epoch 75/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0030 - val_loss: 0.0150
# Epoch 76/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0030 - val_loss: 0.0151
# Epoch 77/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0151
# Epoch 78/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 0.0152
# Epoch 79/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0152
# Epoch 80/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0151
# Epoch 81/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0150
# Epoch 82/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0150
# Epoch 83/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0150
# Epoch 84/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0151
# Epoch 85/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0032 - val_loss: 0.0154
# Epoch 86/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0154
# Epoch 87/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0153
# Epoch 88/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0153
# Epoch 89/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0153
# Epoch 90/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0155
# Epoch 91/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0156
# Epoch 92/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0158
# Epoch 93/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0158
# Epoch 94/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0158
# Epoch 95/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0158
# Epoch 96/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0160
# Epoch 97/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0162
# Epoch 98/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0162
# Epoch 99/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0164
# Epoch 100/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0165
# Epoch 101/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0164
# Epoch 102/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0167
# Epoch 103/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0167
# Epoch 104/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0167
# Epoch 105/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0168
# Epoch 106/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0169
# Epoch 107/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0170
# Epoch 108/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0172
# Epoch 109/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0170
# Epoch 110/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0174
# Epoch 111/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0174
# Epoch 112/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0174
# Epoch 113/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0172
# Epoch 114/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0170
# Epoch 115/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0029 - val_loss: 0.0170
# Epoch 116/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0171
# Epoch 117/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0175
# Epoch 118/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0174
# Epoch 119/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0172
# Epoch 120/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0170
# Epoch 121/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0171
# Epoch 122/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0167
# Epoch 123/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0170
# Epoch 124/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0171
# Epoch 125/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0172
# Epoch 126/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0174
# Epoch 127/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0170
# Epoch 128/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0170
# Epoch 129/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0172
# Epoch 130/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0170
# Epoch 131/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0169
# Epoch 132/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0171
# Epoch 133/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0169
# Epoch 134/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0170
# Epoch 135/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0173
# Epoch 136/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0168
# Epoch 137/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0170
# Epoch 138/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0171
# Epoch 139/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0170
# Epoch 140/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0174
# Epoch 141/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 0.0174
# Epoch 142/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0171
# Epoch 143/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0169
# Epoch 144/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0174
# Epoch 145/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0172
# Epoch 146/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0173
# Epoch 147/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0173
# Epoch 148/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0171
# Epoch 149/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0170
# Epoch 150/150
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0173
# Epoch 1/150
# 20/20 [==============================] - 3s 56ms/step - loss: 0.0170 - val_loss: 0.0209
# Epoch 2/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 0.0146
# Epoch 3/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0070 - val_loss: 0.0133
# Epoch 4/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0049 - val_loss: 0.0135
# Epoch 5/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 6/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 7/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0143
# Epoch 8/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0144
# Epoch 9/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0145
# Epoch 10/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0144
# Epoch 11/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0144
# Epoch 12/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0143
# Epoch 13/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0142
# Epoch 14/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0141
# Epoch 15/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 0.0141
# Epoch 16/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 0.0140
# Epoch 17/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 0.0140
# Epoch 18/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 0.0140
# Epoch 19/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 0.0139
# Epoch 20/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 0.0139
# Epoch 21/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0038 - val_loss: 0.0138
# Epoch 22/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0138
# Epoch 23/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 24/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0137
# Epoch 25/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0136
# Epoch 26/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0137
# Epoch 27/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0137
# Epoch 28/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0138
# Epoch 29/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 0.0140
# Epoch 30/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0137
# Epoch 31/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0135
# Epoch 32/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 0.0136
# Epoch 33/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0137
# Epoch 34/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0137
# Epoch 35/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0138
# Epoch 36/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0138
# Epoch 37/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0138
# Epoch 38/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0138
# Epoch 39/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0139
# Epoch 40/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0139
# Epoch 41/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0028 - val_loss: 0.0139
# Epoch 42/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0028 - val_loss: 0.0139
# Epoch 43/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0028 - val_loss: 0.0139
# Epoch 44/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 0.0139
# Epoch 45/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 46/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 47/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0140
# Epoch 48/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0140
# Epoch 49/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0140
# Epoch 50/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 0.0140
# Epoch 51/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 52/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 53/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 54/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 55/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 56/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 57/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 58/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 59/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0141
# Epoch 60/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 61/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 62/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 63/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 64/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 65/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 66/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 67/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 68/150
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 69/150
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 70/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 71/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 72/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 73/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0141
# Epoch 74/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 75/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0139
# Epoch 76/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0139
# Epoch 77/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 78/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0145
# Epoch 79/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0145
# Epoch 80/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0145
# Epoch 81/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 82/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 83/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 84/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 85/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 86/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 87/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 88/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 89/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 90/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 91/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 92/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 93/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 94/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 95/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 96/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 97/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 98/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 99/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 100/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 101/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 102/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 103/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 104/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 105/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0146
# Epoch 106/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0145
# Epoch 107/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0145
# Epoch 108/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0145
# Epoch 109/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0145
# Epoch 110/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 111/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 112/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0142
# Epoch 113/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0145
# Epoch 114/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0146
# Epoch 115/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0145
# Epoch 116/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0145
# Epoch 117/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0147
# Epoch 118/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0147
# Epoch 119/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0147
# Epoch 120/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0146
# Epoch 121/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 122/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 123/150
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 124/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 125/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 126/150
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 127/150
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 128/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 129/150
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 0.0145
# Epoch 130/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 0.0143
# Epoch 131/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0142
# Epoch 132/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0146
# Epoch 133/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0153
# Epoch 134/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0151
# Epoch 135/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 0.0151
# Epoch 136/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0152
# Epoch 137/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 138/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 139/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 140/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 141/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 142/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 143/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 144/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 145/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 146/150
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 147/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 148/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 149/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 150/150
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0146

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (15, 6), dpi=100)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_gru, 'GRU')
plot_loss (history_lstm, 'LSTM')

# Transform data back to original data space
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction

prediction_gru = prediction(model_gru)
prediction_lstm = prediction(model_lstm)

# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    
    plt.figure(figsize=(15, 6), dpi=100)
    
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), label='Test data')
    plt.plot(np.arange(range_future), np.array(prediction), label='Prediction')
    
    dict_to_dataframe_prediction = {
        "range_future": np.arange(range_future),
        f"prediction{model_name}": np.array(prediction.squeeze())
    }

    dataframe_prediction = pd.DataFrame(dict_to_dataframe_prediction)
    dataframe_prediction.to_csv(f"prediction_plot_cubic_pa-ba_{model_name}.csv", index=False)
    
    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time')
    plt.ylabel('Bits/s')

plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_lstm, 'LSTM', y_test)

# Calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

evaluate_prediction(prediction_gru, y_test, 'GRU')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
# Out:
# 9/9 [==============================] - 1s 5ms/step
# 9/9 [==============================] - 1s 7ms/step
# GRU:
# Mean Absolute Error: 126569935.9667
# Root Mean Square Error: 169964484.8032
#
# LSTM:
# Mean Absolute Error: 123483697.2328
# Root Mean Square Error: 166606315.1481
