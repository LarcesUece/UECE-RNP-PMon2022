# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from scipy import stats
# %matplotlib inline
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU

from matplotlib.pyplot import figure

figure(figsize = (15, 6), dpi = 100)
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados-gru-lstm\lstm\bbr esmond data_sem_outliers 10-18-2022.csv', usecols = [0], engine ='python')
plt.plot(dataset)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 import warnings
#       6 warnings.filterwarnings('ignore')
#
# File c:\Python39\lib\site-packages\matplotlib\pyplot.py:55
#      53 import matplotlib.image
#      54 from matplotlib import _api
# ---> 55 from matplotlib import rcsetup, style
#      56 from matplotlib import _pylab_helpers, interactive
#      57 from matplotlib import cbook
#
# File c:\Python39\lib\site-packages\matplotlib\style\__init__.py:1
# ----> 1 from .core import available, context, library, reload_library, use
#       4 __all__ = ["available", "context", "library", "reload_library", "use"]
#
# File c:\Python39\lib\site-packages\matplotlib\style\core.py:262
#     257         return dict.__getitem__(self, key)
#     260 # Load style library
#     261 # ==================
# --> 262 _base_library = read_style_directory(BASE_LIBRARY_PATH)
#     263 library = _StyleLibrary()
#     264 available = []
#
# File c:\Python39\lib\site-packages\matplotlib\style\core.py:230, in read_style_directory(style_dir)
#     228 for path in Path(style_dir).glob(f"*.{STYLE_EXTENSION}"):
#     229     with warnings.catch_warnings(record=True) as warns:
# --> 230         styles[path.stem] = rc_params_from_file(
#     231             path, use_default_template=False)
#     232     for w in warns:
#     233         _log.warning('In %s: %s', path, w.message)
#
# File c:\Python39\lib\site-packages\matplotlib\__init__.py:862, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     847 def rc_params_from_file(fname, fail_on_error=False, use_default_template=True):
#     848     """
#     849     Construct a `RcParams` from file *fname*.
#     850
#    (...)
#     860         parameters specified in the file. (Useful for updating dicts.)
#     861     """
# --> 862     config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     864     if not use_default_template:
#     865         return config_from_file
#
# File c:\Python39\lib\site-packages\matplotlib\__init__.py:789, in _rc_params_in_file(fname, transform, fail_on_error)
#     787 import matplotlib as mpl
#     788 rc_temp = {}
# --> 789 with _open_file_or_url(fname) as fd:
#     790     try:
#     791         for line_no, line in enumerate(fd, 1):
#
# File c:\Python39\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File c:\Python39\lib\site-packages\matplotlib\__init__.py:766, in _open_file_or_url(fname)
#     764 else:
#     765     fname = os.path.expanduser(fname)
# --> 766     with open(fname, encoding='utf-8') as f:
#     767         yield f
#
# File c:\Python39\lib\codecs.py:309, in BufferedIncrementalDecoder.__init__(self, errors)
#     303 class BufferedIncrementalDecoder(IncrementalDecoder):
#     304     """
#     305     This subclass of IncrementalDecoder can be used as the baseclass for an
#     306     incremental decoder if the decoder must be able to handle incomplete
#     307     byte sequences.
#     308     """
# --> 309     def __init__(self, errors='strict'):
#     310         IncrementalDecoder.__init__(self, errors)
#     311         # undecoded input that is kept between calls to decode()
#
# KeyboardInterrupt:

# %%
# Set random seed to get the same result after each time running the code
tf.random.set_seed(7)

# %%
file = 'bbr esmond data 08-25-2022.csv'
dataset = pd.read_csv(r'D:\git\UECE-RNP-PMon2022\tratados-gru-lstm\lstm\bbr esmond data_sem_outliers 10-18-2022.csv', usecols = [0], engine = 'python')

# %%
# Split train data and test data
train_size = int(len(dataset)*0.7)

# train_data = df.WC.loc[:train_size] -----> it gives a series
# Do not forget use iloc to select a number of rows
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# %%
# Scale data
# The input to scaler.fit -> array-like, sparse matrix, dataframe of shape (n_samples, n_features)
scaler = MinMaxScaler().fit(train_data)

train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
# Create input dataset
# Th input shape should be [samples, time steps, features]
def create_dataset (X, look_back = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
        
    return np.array(Xs), np.array(ys)

X_train, y_train = create_dataset(train_scaled,30)
X_test, y_test = create_dataset(test_scaled,30)

print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
X_test[:33].shape
# Out:
# X_train.shape:  (586, 30, 1)
# y_train.shape:  (586, 1)
# X_test.shape:  (234, 30, 1)
# y_test.shape:  (234, 1)
# (33, 30, 1)

# %%
# Create GRU model
def create_gru(units):
    model = Sequential()
    
    # Input layer 
    model.add(GRU(units = units, return_sequences = True, input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    
    # Hidden layer
    model.add(GRU(units = units))                 
    model.add(Dropout(0.2))
    model.add(Dense(1))
    
    #Compile model
    model.compile(optimizer='adam',loss='mse')
   
    return model
model_gru = create_gru(64)

# Create LSTM model
def create_lstm(units):
    model = Sequential()
    
    # Input layer
    model.add(LSTM(units = units, return_sequences = True, input_shape = [X_train.shape[1], X_train.shape[2]]))
    
    # Hidden layer
    model.add(LSTM(units = units))
    model.add(Dense(1))
    
    #Compile model
    model.compile(optimizer ='adam',loss ='mse')
    
    return model
model_lstm = create_lstm(64)

def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10)
    history = model.fit(X_train, y_train, epochs = 150, validation_split = 0.2, batch_size = 26, shuffle = False)
    return history

history_gru = fit_model(model_gru)
history_lstm = fit_model(model_lstm)
# Out:
# Epoch 1/150
# 18/18 [==============================] - 2s 29ms/step - loss: 0.1925 - val_loss: 0.0362
# Epoch 2/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0226 - val_loss: 0.0281
# Epoch 3/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0161 - val_loss: 0.0274
# Epoch 4/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0152 - val_loss: 0.0277
# Epoch 5/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0150 - val_loss: 0.0273
# Epoch 6/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0147 - val_loss: 0.0272
# Epoch 7/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0145 - val_loss: 0.0268
# Epoch 8/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0138 - val_loss: 0.0267
# Epoch 9/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0261
# Epoch 10/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0258
# Epoch 11/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0261
# Epoch 12/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0252
# Epoch 13/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0250
# Epoch 14/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0247
# Epoch 15/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0247
# Epoch 16/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0242
# Epoch 17/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0241
# Epoch 18/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0127 - val_loss: 0.0241
# Epoch 19/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0113 - val_loss: 0.0236
# Epoch 20/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0115 - val_loss: 0.0234
# Epoch 21/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0233
# Epoch 22/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0114 - val_loss: 0.0232
# Epoch 23/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0116 - val_loss: 0.0233
# Epoch 24/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0227
# Epoch 25/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0112 - val_loss: 0.0232
# Epoch 26/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0117 - val_loss: 0.0223
# Epoch 27/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0115 - val_loss: 0.0221
# Epoch 28/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0113 - val_loss: 0.0223
# Epoch 29/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0108 - val_loss: 0.0220
# Epoch 30/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0219
# Epoch 31/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0115 - val_loss: 0.0216
# Epoch 32/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0113 - val_loss: 0.0214
# Epoch 33/150
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0212
# Epoch 34/150
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0106 - val_loss: 0.0214
# Epoch 35/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0113 - val_loss: 0.0212
# Epoch 36/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0105 - val_loss: 0.0212
# Epoch 37/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.0208
# Epoch 38/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 0.0208
# Epoch 39/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0111 - val_loss: 0.0213
# Epoch 40/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0104 - val_loss: 0.0208
# Epoch 41/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0115 - val_loss: 0.0206
# Epoch 42/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0112 - val_loss: 0.0205
# Epoch 43/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0107 - val_loss: 0.0211
# Epoch 44/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0114 - val_loss: 0.0203
# Epoch 45/150
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0206
# Epoch 46/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0098 - val_loss: 0.0202
# Epoch 47/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.0203
# Epoch 48/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0111 - val_loss: 0.0200
# Epoch 49/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0203
# Epoch 50/150
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0091 - val_loss: 0.0200
# Epoch 51/150
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0202
# Epoch 52/150
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0204
# Epoch 53/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0202
# Epoch 54/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0203
# Epoch 55/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0204
# Epoch 56/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.0200
# Epoch 57/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0200
# Epoch 58/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0198
# Epoch 59/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0197
# Epoch 60/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0204
# Epoch 61/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0202
# Epoch 62/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0199
# Epoch 63/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 0.0201
# Epoch 64/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0197
# Epoch 65/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0105 - val_loss: 0.0198
# Epoch 66/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0199
# Epoch 67/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0197
# Epoch 68/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0198
# Epoch 69/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0197
# Epoch 70/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0198
# Epoch 71/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0198
# Epoch 72/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0095 - val_loss: 0.0213
# Epoch 73/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0204
# Epoch 74/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0096 - val_loss: 0.0198
# Epoch 75/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0205
# Epoch 76/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0202
# Epoch 77/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0199
# Epoch 78/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0205
# Epoch 79/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0204
# Epoch 80/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0204
# Epoch 81/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0204
# Epoch 82/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0198
# Epoch 83/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0201
# Epoch 84/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0199
# Epoch 85/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.0200
# Epoch 86/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0199
# Epoch 87/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0199
# Epoch 88/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0102 - val_loss: 0.0203
# Epoch 89/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0197
# Epoch 90/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0201
# Epoch 91/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0092 - val_loss: 0.0200
# Epoch 92/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0203
# Epoch 93/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0092 - val_loss: 0.0201
# Epoch 94/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0206
# Epoch 95/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0197
# Epoch 96/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0201
# Epoch 97/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0205
# Epoch 98/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0200
# Epoch 99/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0205
# Epoch 100/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0091 - val_loss: 0.0199
# Epoch 101/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0198
# Epoch 102/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0088 - val_loss: 0.0198
# Epoch 103/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0101 - val_loss: 0.0203
# Epoch 104/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0204
# Epoch 105/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0200
# Epoch 106/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0200
# Epoch 107/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0099 - val_loss: 0.0197
# Epoch 108/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0197
# Epoch 109/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0204
# Epoch 110/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0203
# Epoch 111/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0207
# Epoch 112/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0200
# Epoch 113/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0202
# Epoch 114/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0202
# Epoch 115/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0090 - val_loss: 0.0201
# Epoch 116/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0201
# Epoch 117/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.0197
# Epoch 118/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0092 - val_loss: 0.0201
# Epoch 119/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0201
# Epoch 120/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0199
# Epoch 121/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0091 - val_loss: 0.0212
# Epoch 122/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0200
# Epoch 123/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0198
# Epoch 124/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0098 - val_loss: 0.0199
# Epoch 125/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.0200
# Epoch 126/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0198
# Epoch 127/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0199
# Epoch 128/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0197
# Epoch 129/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.0198
# Epoch 130/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0198
# Epoch 131/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0202
# Epoch 132/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0204
# Epoch 133/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0197
# Epoch 134/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0092 - val_loss: 0.0202
# Epoch 135/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 0.0199
# Epoch 136/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 0.0196
# Epoch 137/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0197
# Epoch 138/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0198
# Epoch 139/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0197
# Epoch 140/150
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0196
# Epoch 141/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0197
# Epoch 142/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0196
# Epoch 143/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0198
# Epoch 144/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0197
# Epoch 145/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0196
# Epoch 146/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0195
# Epoch 147/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0195
# Epoch 148/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.0197
# Epoch 149/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.0198
# Epoch 150/150
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.0194
# Epoch 1/150
# 18/18 [==============================] - 2s 34ms/step - loss: 0.1275 - val_loss: 0.0499
# Epoch 2/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0183 - val_loss: 0.0307
# Epoch 3/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0121 - val_loss: 0.0323
# Epoch 4/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.0310
# Epoch 5/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0305
# Epoch 6/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0303
# Epoch 7/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0108 - val_loss: 0.0301
# Epoch 8/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0108 - val_loss: 0.0300
# Epoch 9/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0298
# Epoch 10/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0297
# Epoch 11/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0296
# Epoch 12/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.0294
# Epoch 13/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.0293
# Epoch 14/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0105 - val_loss: 0.0292
# Epoch 15/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0104 - val_loss: 0.0291
# Epoch 16/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0104 - val_loss: 0.0290
# Epoch 17/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0103 - val_loss: 0.0289
# Epoch 18/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0103 - val_loss: 0.0288
# Epoch 19/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0102 - val_loss: 0.0287
# Epoch 20/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0102 - val_loss: 0.0285
# Epoch 21/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0101 - val_loss: 0.0284
# Epoch 22/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0101 - val_loss: 0.0283
# Epoch 23/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0100 - val_loss: 0.0282
# Epoch 24/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0099 - val_loss: 0.0281
# Epoch 25/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0099 - val_loss: 0.0280
# Epoch 26/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0098 - val_loss: 0.0278
# Epoch 27/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0098 - val_loss: 0.0277
# Epoch 28/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0097 - val_loss: 0.0276
# Epoch 29/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0097 - val_loss: 0.0274
# Epoch 30/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0096 - val_loss: 0.0273
# Epoch 31/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0096 - val_loss: 0.0271
# Epoch 32/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0095 - val_loss: 0.0269
# Epoch 33/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0094 - val_loss: 0.0267
# Epoch 34/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0093 - val_loss: 0.0265
# Epoch 35/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0263
# Epoch 36/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0091 - val_loss: 0.0260
# Epoch 37/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0090 - val_loss: 0.0257
# Epoch 38/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0089 - val_loss: 0.0254
# Epoch 39/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0088 - val_loss: 0.0250
# Epoch 40/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0087 - val_loss: 0.0247
# Epoch 41/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0086 - val_loss: 0.0243
# Epoch 42/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 43/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 44/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 0.0234
# Epoch 45/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0232
# Epoch 46/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0230
# Epoch 47/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0229
# Epoch 48/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0227
# Epoch 49/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0226
# Epoch 50/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0224
# Epoch 51/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0223
# Epoch 52/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0222
# Epoch 53/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0221
# Epoch 54/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0219
# Epoch 55/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0218
# Epoch 56/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0078 - val_loss: 0.0217
# Epoch 57/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0078 - val_loss: 0.0216
# Epoch 58/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0078 - val_loss: 0.0215
# Epoch 59/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0078 - val_loss: 0.0214
# Epoch 60/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0213
# Epoch 61/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0212
# Epoch 62/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0211
# Epoch 63/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0210
# Epoch 64/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0209
# Epoch 65/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0208
# Epoch 66/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0207
# Epoch 67/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0206
# Epoch 68/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0205
# Epoch 69/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0205
# Epoch 70/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0204
# Epoch 71/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0203
# Epoch 72/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0202
# Epoch 73/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0202
# Epoch 74/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0201
# Epoch 75/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0200
# Epoch 76/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0199
# Epoch 77/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0199
# Epoch 78/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0198
# Epoch 79/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0198
# Epoch 80/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 81/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 82/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 83/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 84/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 85/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 86/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0198
# Epoch 87/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0198
# Epoch 88/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0197
# Epoch 89/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0197
# Epoch 90/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0197
# Epoch 91/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0197
# Epoch 92/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0197
# Epoch 93/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 94/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 95/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 96/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 97/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 98/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 99/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 100/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 101/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 102/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 103/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 104/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0197
# Epoch 105/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0198
# Epoch 106/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0198
# Epoch 107/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 108/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 109/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 110/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 111/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 112/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 113/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 114/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 115/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 116/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 117/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 118/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 119/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 120/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 121/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 122/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 123/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 124/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 125/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 126/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 127/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 128/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 129/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0198
# Epoch 130/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 131/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 132/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 133/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 134/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 135/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 136/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 137/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 138/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0198
# Epoch 139/150
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 140/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 141/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 142/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 143/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 144/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 145/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 146/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 147/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 148/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 149/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0197
# Epoch 150/150
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0197

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (15, 6), dpi=100)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_gru, 'GRU')
plot_loss (history_lstm, 'LSTM')

# Transform data back to original data space
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction

prediction_gru = prediction(model_gru)
prediction_lstm = prediction(model_lstm)

# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    
    plt.figure(figsize=(15, 6), dpi=100)
    
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), label='Test data')
    plt.plot(np.arange(range_future), np.array(prediction), label='Prediction')
    
    dict_to_dataframe_prediction = {
        "range_future": np.arange(range_future),
        f"prediction{model_name}": np.array(prediction.squeeze())
    }

    dataframe_prediction = pd.DataFrame(dict_to_dataframe_prediction)
    dataframe_prediction.to_csv(f"prediction_plot_bbr{model_name}.csv", index=False)
    
    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time')
    plt.ylabel('Bits/s')

plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_lstm, 'LSTM', y_test)

# Calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

evaluate_prediction(prediction_gru, y_test, 'GRU')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
# Out:
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 5ms/step
# GRU:
# Mean Absolute Error: 5171403.8564
# Root Mean Square Error: 9098875.7536
#
# LSTM:
# Mean Absolute Error: 5338053.4120
# Root Mean Square Error: 9426105.6855
